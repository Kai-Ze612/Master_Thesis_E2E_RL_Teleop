# %%
import mujoco
import os
from mujoco import viewer
import re

# %%
# Get the absolute path to your FR3 model

fr3_xml_path = "/media/kai/Kai_Backup/Master_Study/Master_Thesis/Implementation/libfranka_ws/src/multipanda_ros2/franka_description/mujoco/franka/scene_ng.xml"

# %%
model = mujoco.MjModel.from_xml_path(fr3_xml_path)
data = mujoco.MjData(model)

# %%
viewer.launch(model, data)
